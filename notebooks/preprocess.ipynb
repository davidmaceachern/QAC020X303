# %%
# !pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /Users/david.maceachern/.pyenv/versions/3.7.0/lib/python3.7/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /Users/david.maceachern/.pyenv/versions/3.7.0/lib/python3.7/site-packages (from sklearn) (0.21.2)
# Requirement already satisfied: scipy>=0.17.0 in /Users/david.maceachern/.pyenv/versions/3.7.0/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.3.0)
# Requirement already satisfied: numpy>=1.11.0 in /Users/david.maceachern/.pyenv/versions/3.7.0/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.16.3)
# Requirement already satisfied: joblib>=0.11 in /Users/david.maceachern/.pyenv/versions/3.7.0/lib/python3.7/site-packages (from scikit-learn->sklearn) (0.13.2)

# %%
# import dependencies
from sklearn import preprocessing
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plotty
import missingno as msno
# %matplotlib inline

# %%
# Load the datasets
df = pd.read_csv('../data/raw/01_06_2014_until_04_06_2019.csv')

# %%
# We can load the 1gb master csv of postcode data into memory with pandas
postcode_data = pd.read_csv('../data/raw/NSPL_MAY_2019_UK.csv', low_memory=False)

# %%
msno.matrix(pricing_data)

# %%
msno.matrix(postcode_data)

# %%
pricing_data.deed_date.describe()
# Out:
# count         345551
# unique          1592
# top       31/03/2016
# freq            3086
# Name: deed_date, dtype: object

# %%
pricing_data.deed_date.order

# %%
pricing_data.head()
# Out:
#                               unique_id  price_paid  deed_date postcode  \
# 0  8355F008-E750-55C5-E053-6B04A8C0D090      233500 2018-11-26   E1 0AD
# 1  6ADB7B46-76D2-4FB8-BA12-DEEECB58CEB2      270000 2014-08-07   E1 0AD
# 2  8355F008-E752-55C5-E053-6B04A8C0D090      176000 2018-06-12   E1 0AD
# 3  4E95D758-19CD-EDA1-E050-A8C0630539E2      450000 2017-03-31   E1 0AE
# 4  5376B385-4F7D-34C1-E053-6B04A8C09FF6      440000 2017-05-23   E1 0AE
#
#   property_type new_build estate_type    saon                  paon  \
# 0             F         N           L  FLAT 4  BILL FAUST HOUSE, 20
# 1             F         N           L  FLAT 8  BILL FAUST HOUSE, 20
# 2             F         N           L  FLAT 5  ADAM MEERE HOUSE, 24
# 3             F         N           L     NaN                   296
# 4             F         N           L     NaN                   314
#
#            street locality    town       district          county  \
# 0  TARLING STREET      NaN  LONDON  TOWER HAMLETS  GREATER LONDON
# 1  TARLING STREET      NaN  LONDON  TOWER HAMLETS  GREATER LONDON
# 2  TARLING STREET      NaN  LONDON  TOWER HAMLETS  GREATER LONDON
# 3    CABLE STREET      NaN  LONDON  TOWER HAMLETS  GREATER LONDON
# 4    CABLE STREET      NaN  LONDON  TOWER HAMLETS  GREATER LONDON
#
#   transaction_category                                    linked_data_url
# 0                    A  http://landregistry.data.gov.uk/data/ppi/trans...
# 1                    A  http://landregistry.data.gov.uk/data/ppi/trans...
# 2                    A  http://landregistry.data.gov.uk/data/ppi/trans...
# 3                    B  http://landregistry.data.gov.uk/data/ppi/trans...
# 4                    A  http://landregistry.data.gov.uk/data/ppi/trans...

# %%
pricing_data.sort_values(by=['deed_date'])
# Out:
#                                    unique_id  price_paid  deed_date  postcode  \
# 252181  251D6F40-F7C9-49A6-AF9E-40F2D682137F      250000 2014-01-06  SW16 4AQ
# 40317   92B21AD5-39BD-47F2-8906-C6186770481A      235000 2014-01-06   E18 1FF
# 214191  5CE703F4-457C-4902-B1B9-25F065A8F8CC      205000 2014-01-07   SE4 1UY
# 340283  F2BF0719-32B0-4531-B98D-31D7ABED0456      490000 2014-01-07    W9 3BL
# 112115  5E590993-DE0B-4A23-9637-76C0AB2C5D99     1270000 2014-01-07    N7 6JG
# 320324  204B09F3-F340-40D4-AA47-BA03F13E006F      873000 2014-01-07    W2 4ET
# 193730  5380E51B-BD0B-47A9-8E18-BEFE5883BA95      250000 2014-01-07  SE20 8EN
# 295608             T         N           F                NaN
# 111951             F         N           L  GROUND FLOOR FLAT
# 311678             T         N           F                NaN
# 138640             T         N           F                NaN
# 45683              F         N           L           FLAT 517
# ...              ...       ...         ...                ...
# 258403             S         N           F                NaN
# 79923              T         N           F                NaN
# 276962             F         N           L             FLAT H
# 60180              T         N           F                NaN
# 337310             F         N           L            FLAT 15
# 314910             F         N           L           FLAT 14A
# 3737               F         Y           L           FLAT 304
# 80344              T         N           F                NaN
# 334635             F         N           L                NaN
# 277055             T         N           F                NaN
# 265689             T         N           F                NaN
# 310561             F         N           L                NaN
# 104859             T         N           F                NaN
# 305978             S         N           F                NaN
# 15512              F         N           L            FLAT 10
# 236285             T         N           F                NaN
# 178152             F         N           L                NaN
# 78317              F         N           L             FLAT 2
# 244768             F         N           L                NaN
# 22102              F         N           L           FLAT 403
# 261382             F         N           L                NaN
# 243771             T         N           F                NaN
# 273314             F         N           L            FLAT 42
# 266561             F         N           L                NaN
# 133947             F         N           L            FLAT 22
# 283997             T         N           F                NaN
# 214580             T         N           F                NaN
# 108066             F         N           L             FLAT 5
# 79637              F         N           L  GROUND FLOOR FLAT
# 324600             F         N           L                NaN
#
#                           paon                   street  locality    town  \
# 252181                   1455A              LONDON ROAD       NaN  LONDON
# 40317         SCENIX HOUSE, 86            CHIGWELL ROAD       NaN  LONDON
# 214191        LEIGH COURT, 213             LEWISHAM WAY       NaN  LONDON
# 340283                     249            PORTNALL ROAD       NaN  LONDON
# 112115                      26             WINDSOR ROAD       NaN  LONDON
# 320324      THE LIMES, 34 - 36           LINDEN GARDENS       NaN  LONDON
# 193730             DOVER HOUSE             ANERLEY ROAD       NaN  LONDON
# 99273                HIGHLANDS      OAKLEIGH ROAD NORTH       NaN  LONDON
# 196236         FELBRIDGE HOUSE   DOG KENNEL HILL ESTATE       NaN  LONDON
# 295561                      67            REPORTON ROAD       NaN  LONDON
# 307449      CRANSTON COURT, 56        BLOEMFONTEIN ROAD       NaN  LONDON
# 312505        ABBOTSBURY HOUSE          ABBOTSBURY ROAD       NaN  LONDON
# 312518                      58         ABBOTSBURY CLOSE       NaN  LONDON
# 298144           SEYMOUR HOUSE            ALBION AVENUE       NaN  LONDON
# 209196                       4           CROWFOOT CLOSE       NaN  LONDON
# 7159                FLAT 3, 20        FOREST DRIVE WEST       NaN  LONDON
# 78928                       50            WOODLAND RISE       NaN  LONDON
# 142850                      41          ST JULIANS ROAD       NaN  LONDON
# 274206   LEWCOS HOUSE, 57 - 63           REGENCY STREET       NaN  LONDON
# 192699                      14             PRINCES ROAD       NaN  LONDON
# 177025                      27            GLENGALL ROAD       NaN  LONDON
# 206502           LUCILLE HOUSE               PARK COURT       NaN  LONDON
# 261174                      73        BARTHOLOMEW CLOSE       NaN  LONDON
# 128004                      15           SINCLAIR GROVE       NaN  LONDON
# 325655                       1             BEDFORD ROAD       NaN  LONDON
# 295608                      23              ORBAIN ROAD    FULHAM  LONDON
# 111951                      78           AXMINSTER ROAD       NaN  LONDON
# 311678                     135              BLYTHE ROAD       NaN  LONDON
# 138640                      34          GRAFTON TERRACE       NaN  LONDON
# 45683     CITY VIEW HOUSE, 463       BETHNAL GREEN ROAD       NaN  LONDON
# ...                        ...                      ...       ...     ...
# 258403                     214              COWICK ROAD       NaN  LONDON
# 79923                       33     LOWER MAIDSTONE ROAD       NaN  LONDON
# 276962                      80             EATON SQUARE       NaN  LONDON
# 60180                       12              DENNY CLOSE       NaN  LONDON
# 337310        SUTHERLAND HOUSE             MARLOES ROAD       NaN  LONDON
# 314910       HARMONT HOUSE, 20            HARLEY STREET       NaN  LONDON
# 3737            LUXE TOWER, 12              DOCK STREET       NaN  LONDON
# 80344                       39             HALTON CLOSE       NaN  LONDON
# 334635                      62             COLWITH ROAD       NaN  LONDON
# 277055                       2           CHESTER SQUARE       NaN  LONDON
# 265689                      58          TRENTHAM STREET       NaN  LONDON
# 310561                      4A          BROOMFIELD ROAD       NaN  LONDON
# 104859                       3                EADE ROAD       NaN  LONDON
# 305978                      28          CHEPSTOW VILLAS       NaN  LONDON
# 15512                       11         MILLENNIUM DRIVE       NaN  LONDON
# 236285                      66           HONEYWELL ROAD       NaN  LONDON
# 178152                      57                LUCEY WAY       NaN  LONDON
# 78317             NICOLL COURT              SYDNEY ROAD       NaN  LONDON
# 244768                     46B      LOWER RICHMOND ROAD       NaN  LONDON
# 22102      ROOSEVELT TOWER, 18       WILLIAMSBURG PLAZA       NaN  LONDON
# 261382                     44B              SANTOS ROAD       NaN  LONDON
# 243771                      15       PAYNESFIELD AVENUE       NaN  LONDON
# 273314    BUCKINGHAM COURT, 78          BUCKINGHAM GATE       NaN  LONDON
# 266561                     60A      WIMBLEDON PARK ROAD       NaN  LONDON
# 133947  ORMONDE COURT, 10 - 14            BELSIZE GROVE       NaN  LONDON
# 283997                       3         CANNON HILL LANE       NaN  LONDON
# 214580                     222           DRAKEFELL ROAD  BROCKLEY  LONDON
# 108066                       6  MOUNT PLEASANT CRESCENT   HORNSEY  LONDON
# 79637                        5               NATAL ROAD       NaN  LONDON
# 324600                       5              MANOR COURT       NaN  LONDON
#
#                       district          county transaction_category  \
# 252181                 CROYDON  GREATER LONDON                    A
# 40317                REDBRIDGE  GREATER LONDON                    A
# 214191                LEWISHAM  GREATER LONDON                    A
# 340283     CITY OF WESTMINSTER  GREATER LONDON                    A
# 112115               ISLINGTON  GREATER LONDON                    A
# 320324  KENSINGTON AND CHELSEA  GREATER LONDON                    A
# 193730                 BROMLEY  GREATER LONDON                    A
# 99273                   BARNET  GREATER LONDON                    A
# 196236               SOUTHWARK  GREATER LONDON                    A
# 295561  HAMMERSMITH AND FULHAM  GREATER LONDON                    A
# 307449  HAMMERSMITH AND FULHAM  GREATER LONDON                    A
# 312505  KENSINGTON AND CHELSEA  GREATER LONDON                    B
# 312518  KENSINGTON AND CHELSEA  GREATER LONDON                    A
# 298144                 LAMBETH  GREATER LONDON                    A
# 209196               GREENWICH  GREATER LONDON                    B
# 7159            WALTHAM FOREST  GREATER LONDON                    A
# 78928                 HARINGEY  GREATER LONDON                    A
# 142850                   BRENT  GREATER LONDON                    A
# 274206     CITY OF WESTMINSTER  GREATER LONDON                    A
# 192699                 BROMLEY  GREATER LONDON                    A
# 177025               SOUTHWARK  GREATER LONDON                    A
# 206502                 BROMLEY  GREATER LONDON                    A
# 261174              WANDSWORTH  GREATER LONDON                    A
# 128004                  BARNET  GREATER LONDON                    A
# 325655                  EALING  GREATER LONDON                    A
# 295608  HAMMERSMITH AND FULHAM  GREATER LONDON                    A
# 111951               ISLINGTON  GREATER LONDON                    A
# 311678  HAMMERSMITH AND FULHAM  GREATER LONDON                    B
# 138640                  CAMDEN  GREATER LONDON                    A
# 45683            TOWER HAMLETS  GREATER LONDON                    A
# ...                        ...             ...                  ...
# 258403              WANDSWORTH  GREATER LONDON                    B
# 79923                  ENFIELD  GREATER LONDON                    A
# 276962     CITY OF WESTMINSTER  GREATER LONDON                    A
# 60180                   NEWHAM  GREATER LONDON                    A
# 337310  KENSINGTON AND CHELSEA  GREATER LONDON                    A
# 314910     CITY OF WESTMINSTER  GREATER LONDON                    A
# 3737             TOWER HAMLETS  GREATER LONDON                    B
# 80344                   BARNET  GREATER LONDON                    A
# 334635  HAMMERSMITH AND FULHAM  GREATER LONDON                    A
# 277055     CITY OF WESTMINSTER  GREATER LONDON                    A
# 265689              WANDSWORTH  GREATER LONDON                    A
# 310561                  EALING  GREATER LONDON                    A
# 104859                HARINGEY  GREATER LONDON                    A
# 305978  KENSINGTON AND CHELSEA  GREATER LONDON                    A
# 15512            TOWER HAMLETS  GREATER LONDON                    A
# 236285              WANDSWORTH  GREATER LONDON                    A
# 178152               SOUTHWARK  GREATER LONDON                    A
# 78317                   BARNET  GREATER LONDON                    A
# 244768              WANDSWORTH  GREATER LONDON                    A
# 22102            TOWER HAMLETS  GREATER LONDON                    A
# 261382              WANDSWORTH  GREATER LONDON                    A
# 243771    RICHMOND UPON THAMES  GREATER LONDON                    A
# 273314     CITY OF WESTMINSTER  GREATER LONDON                    A
# 266561              WANDSWORTH  GREATER LONDON                    B
# 133947                  CAMDEN  GREATER LONDON                    A
# 283997                  MERTON  GREATER LONDON                    A
# 214580                LEWISHAM  GREATER LONDON                    A
# 108066                HARINGEY  GREATER LONDON                    A
# 79637                  ENFIELD  GREATER LONDON                    A
# 324600                HOUNSLOW  GREATER LONDON                    A
#
#                                           linked_data_url
# 252181  http://landregistry.data.gov.uk/data/ppi/trans...
# 40317   http://landregistry.data.gov.uk/data/ppi/trans...
# 214191  http://landregistry.data.gov.uk/data/ppi/trans...
# 340283  http://landregistry.data.gov.uk/data/ppi/trans...
# 112115  http://landregistry.data.gov.uk/data/ppi/trans...
# 320324  http://landregistry.data.gov.uk/data/ppi/trans...
# 193730  http://landregistry.data.gov.uk/data/ppi/trans...
# 99273   http://landregistry.data.gov.uk/data/ppi/trans...
# 196236  http://landregistry.data.gov.uk/data/ppi/trans...
# 295561  http://landregistry.data.gov.uk/data/ppi/trans...
# 307449  http://landregistry.data.gov.uk/data/ppi/trans...
# 312505  http://landregistry.data.gov.uk/data/ppi/trans...
# 312518  http://landregistry.data.gov.uk/data/ppi/trans...
# 298144  http://landregistry.data.gov.uk/data/ppi/trans...
# 209196  http://landregistry.data.gov.uk/data/ppi/trans...
# 7159    http://landregistry.data.gov.uk/data/ppi/trans...
unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
pricing_data.estate_type.unique()
# Out:
# array(['L', 'F'], dtype=object)

# %%
pricing_data.district.unique()
# Out:
# array(['TOWER HAMLETS', 'CITY OF LONDON', 'HACKNEY', 'HARROW',
#        'WALTHAM FOREST', 'REDBRIDGE', 'HARINGEY', 'NEWHAM',
#        'BARKING AND DAGENHAM', 'LEWISHAM', 'LAMBETH', 'SOUTHWARK',
#        'WANDSWORTH', 'GREENWICH', 'BRENT', 'EALING', 'HOUNSLOW',
#        'ENFIELD', 'HILLINGDON', 'EPPING FOREST', 'ISLINGTON', 'CAMDEN',
#        'CITY OF WESTMINSTER', 'BARNET', 'HAMMERSMITH AND FULHAM',
#        'HARLOW', 'CROYDON', 'BROMLEY', 'BEXLEY', 'SUTTON',
#        'KINGSTON UPON THAMES', 'KENSINGTON AND CHELSEA',
#        'RICHMOND UPON THAMES', 'MERTON'], dtype=object)

# %%
pricing_data.transaction_category.unique()
# Out:
# array(['A', 'B'], dtype=object)

# %%
df = df[['price_paid', 'deed_date','property_type','new_build', 'estate_type', 'district','transaction_category']]

# %%
# price_paid               int64 [233500, 270000, 176000, 450000, 440000]
# money, possibly look into normalizing
# deed_date               object ['05/07/2017', '05/07/2017', '05/07/2017', '05/07/2017', '05/07/2017']
# date object convert to timestamp and then add days since value
# property_type           object ['F', 'T', 'O', 'S', 'D']
# categorical data perform label encoder
# new_build               object ['N', 'Y']
# categorical data perform label encoder
# estate_type             object ['L', 'F']
# categorical data perform label encoder
# district                object ['TOWER HAMLETS', 'CITY OF LONDON', 'HACKNEY', 'HARROW', 'WALTHAM FOREST']
# categorical data perform label encoder
# transaction_category    object ['A', 'B']
# categorical data perform label encoder

# %%
def plot_corr(df, size=10):
    """
    Function plots a graphical correlation matrix for each pair of columns in the dataframe.

    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot
    
    Displays:
        matrix of correlation between columns. Blue-cyan-yellow-red-darkred => less to more correlated
                                               0 ------------------>  1
                                               Expect a darkred line running from top left to bottom right
    """
    
    corr = df.corr()    ## data frame correlation function
    fig, ax = plotty.subplots(figsize=(size, size))
    ax.matshow(corr)    # color code the rectangles by correlation value
    plotty.xticks(range(len(corr.columns)), corr.columns) # draw x tick marks
    plotty.yticks(range(len(corr.columns)), corr.columns) # draw y tick marks

plot_corr(df)

# %%
# Drop variables we're not interested in
df.drop(['unique_id', 'paon', 'saon', 'linked_data_url', 'street', 'locality', 'county', 'town','postcode'], axis=1)
# Out:
#         price_paid  deed_date  property_type  new_build  estate_type  \
# 0           233500 2018-11-26              1          0            1
# 1           270000 2014-08-07              1          0            1
# 2           176000 2018-06-12              1          0            1
# 3           450000 2017-03-31              1          0            1
# 4           440000 2017-05-23              1          0            1
# 5           430500 2018-10-18              1          0            1
# 6           390000 2018-12-19              1          0            1
# 7           490000 2017-04-09              1          0            1
# 8           455000 2015-10-23              1          0            1
# 9           378000 2015-08-25              1          0            1
# 10          410000 2018-03-29              1          0            1
# 11          450000 2015-06-18              1          0            1
# 12          265000 2018-03-28              1          0            1
# 13          200000 2014-09-30              1          0            1
# 14          238000 2014-07-15              1          0            1
# 15          225000 2015-02-10              1          0            1
# 16          130000 2014-05-12              1          0            1
# 17          120000 2014-07-07              1          0            1
# 18          340000 2015-10-30              1          0            1
# 19          450000 2015-04-09              1          0            1
# 20          465000 2015-07-17              1          0            1
# 21          495000 2015-12-06              1          0            1
# 10       1543 days
# 11        528 days
# 12       1542 days
# 13        267 days
# 14        190 days
# 15        400 days
# 16        126 days
# 17        182 days
# 18        662 days
# 19        458 days
# 20        557 days
# 21        699 days
# 22        592 days
# 23        319 days
# 24       1974 days
# 25       1764 days
# 26       1424 days
# 27        961 days
# 28        324 days
# 29        409 days
#             ...
# 345521   1205 days
# 345522   1205 days
# 345523   1205 days
# 345524   1205 days
# 345525   1205 days
# 345526   1205 days
# 345527   1205 days
# 345528   1205 days
# 345529   1205 days
# 345530   1205 days
# 345531   1205 days
# 345532   1205 days
# 345533   1205 days
# 345534   1205 days
# 345535   1205 days
# 345536   1205 days
# 345537   1205 days
# 345538   1205 days
# 345539   1205 days
# 345540   1205 days
# 345541   1217 days
# 345542   1217 days
# 345543   1217 days
# 345544   1217 days
# 345545   1217 days
# 345546   1217 days
# 345547   1217 days
# 345548   1217 days
# 345549   1217 days
# 345550   1217 days
# Name: deed_date, Length: 345551, dtype: timedelta64[ns]

# %%
df.head()
# Out:
#                               unique_id  price_paid  deed_date postcode  \
# 0  8355F008-E750-55C5-E053-6B04A8C0D090      233500 2018-11-26   E1 0AD
# 1  6ADB7B46-76D2-4FB8-BA12-DEEECB58CEB2      270000 2014-08-07   E1 0AD
# 2  8355F008-E752-55C5-E053-6B04A8C0D090      176000 2018-06-12   E1 0AD
# 3  4E95D758-19CD-EDA1-E050-A8C0630539E2      450000 2017-03-31   E1 0AE
# 4  5376B385-4F7D-34C1-E053-6B04A8C09FF6      440000 2017-05-23   E1 0AE
#
#    property_type  new_build  estate_type    saon                  paon  \
# 0              1          0            1  FLAT 4  BILL FAUST HOUSE, 20
# 1              1          0            1  FLAT 8  BILL FAUST HOUSE, 20
# 2              1          0            1  FLAT 5  ADAM MEERE HOUSE, 24
# 3              1          0            1     NaN                   296
# 4              1          0            1     NaN                   314
#
#            street locality    town  district          county  \
# 0  TARLING STREET      NaN  LONDON        31  GREATER LONDON
# 1  TARLING STREET      NaN  LONDON        31  GREATER LONDON
# 2  TARLING STREET      NaN  LONDON        31  GREATER LONDON
# 3    CABLE STREET      NaN  LONDON        31  GREATER LONDON
# 4    CABLE STREET      NaN  LONDON        31  GREATER LONDON
#
#    transaction_category                                    linked_data_url
# 0                     0  http://landregistry.data.gov.uk/data/ppi/trans...
# 1                     0  http://landregistry.data.gov.uk/data/ppi/trans...
# 2                     0  http://landregistry.data.gov.uk/data/ppi/trans...
# 3                     1  http://landregistry.data.gov.uk/data/ppi/trans...
# 4                     0  http://landregistry.data.gov.uk/data/ppi/trans...

# %%
# price_paid               int64 [233500, 270000, 176000, 450000, 440000]
# money, possibly look into normalizing
# deed_date               object ['05/07/2017', '05/07/2017', '05/07/2017', '05/07/2017', '05/07/2017']
# date object convert to timestamp and then add days since value
# property_type           object ['F', 'T', 'O', 'S', 'D']
# categorical data perform label encoder
# new_build               object ['N', 'Y']
# categorical data perform label encoder
# estate_type             object ['L', 'F']
# categorical data perform label encoder
# district                object ['TOWER HAMLETS', 'CITY OF LONDON', 'HACKNEY', 'HARROW', 'WALTHAM FOREST']
# categorical data perform label encoder
# transaction_category    object ['A', 'B']
# categorical data perform label encoder

# %%
df['property_type'] = df[['property_type']].apply(preprocessing.LabelEncoder().fit_transform)
df['new_build'] = df[['new_build']].apply(preprocessing.LabelEncoder().fit_transform)
df['estate_type'] = df[['estate_type']].apply(preprocessing.LabelEncoder().fit_transform)
df['district'] = df[['district']].apply(preprocessing.LabelEncoder().fit_transform)
df['transaction_category'] = df[['transaction_category']].apply(preprocessing.LabelEncoder().fit_transform)
# df['days_since'] = df.loc['deed_date'].apply(days_since)

# %%
# Create a label (category) encoder object
le = preprocessing.LabelEncoder()
#%%
# Fit the encoder to the pandas column
le.fit(df['property_type'])
#%%
# View the labels
list(le.classes_)
#%%
# Apply the fitted encoder to the pandas column
df['property_type_transform'] = le.transform(df['property_type'])

# %%
selected_columns = pricing_data[['price_paid', 'deed_date', 'property_type', 'new_build', 'estate_type', 'street','district', 'county', 'transaction_category']]

# %%
pricing_data = pricing_data[['price_paid', 'deed_date', 'property_type', 'new_build', 'estate_type','district', 'transaction_category']]

# %%
pricing_data.dtypes
# Out:
# price_paid                       int64
# deed_date               datetime64[ns]
# property_type                   object
# new_build                       object
# estate_type                     object
# district                        object
# transaction_category            object
# dtype: object

# %%
pricing_data.head()
# Out:
#    price_paid  deed_date property_type new_build estate_type       district  \
# 0      233500 2018-11-26             F         N           L  TOWER HAMLETS
# 1      270000 2014-08-07             F         N           L  TOWER HAMLETS
# 2      176000 2018-06-12             F         N           L  TOWER HAMLETS
# 3      450000 2017-03-31             F         N           L  TOWER HAMLETS
# 4      440000 2017-05-23             F         N           L  TOWER HAMLETS
#
#   transaction_category
# 0                    A
# 1                    A
# 2                    A
# 3                    B
# 4                    A

# %%
pricing_data.head().deed_date.apply(days_since)
# Out:
# 0   1785 days
# 1    213 days
# 2   1618 days
# 3   1180 days
# 4   1233 days
# Name: deed_date, dtype: timedelta64[ns]

# %%
selected_columns['district'].unique()
# Out:
# array(['TOWER HAMLETS', 'CITY OF LONDON', 'HACKNEY', 'HARROW',
#        'WALTHAM FOREST', 'REDBRIDGE', 'HARINGEY', 'NEWHAM',
#        'BARKING AND DAGENHAM', 'LEWISHAM', 'LAMBETH', 'SOUTHWARK',
#        'WANDSWORTH', 'GREENWICH', 'BRENT', 'EALING', 'HOUNSLOW',
#        'ENFIELD', 'HILLINGDON', 'EPPING FOREST', 'ISLINGTON', 'CAMDEN',
#        'CITY OF WESTMINSTER', 'BARNET', 'HAMMERSMITH AND FULHAM',
#        'HARLOW', 'CROYDON', 'BROMLEY', 'BEXLEY', 'SUTTON',
#        'KINGSTON UPON THAMES', 'KENSINGTON AND CHELSEA',
#        'RICHMOND UPON THAMES', 'MERTON'], dtype=object)

# %%
list(pricing_data.deed_date.head())
# Out:
# [Timestamp('2018-11-26 00:00:00'),
#  Timestamp('2014-08-07 00:00:00'),
#  Timestamp('2018-06-12 00:00:00'),
#  Timestamp('2017-03-31 00:00:00'),
#  Timestamp('2017-05-23 00:00:00')]

# %%
# Create features for year, month, day, hour, and minute
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day

# %%
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
plotty.plot([1,2])
savefig('test.png', bbox_inches='tight')
